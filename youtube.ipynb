# %%
# !pip install youtube-transcript-api
# !pip install pytube3
# Out:
# ...
#   Using cached pytube3-9.6.4-py3-none-any.whl (38 kB)
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import json

# %%
caption_TL_1 = YouTubeTranscriptApi.get_transcript('2Nb2gVah_44')
with open('TL_1.json','w') as file:
    json.dump(caption_TL_1, file, indent = 4, sort_keys = False)

# %%
caption_TL_2 = YouTubeTranscriptApi.get_transcript('8EDwr1pFr_w')
with open('TL_2.json','w') as file:
    json.dump(caption_TL_2, file, indent = 4, sort_keys = False)

# %%
# !python data_prep.py
# Out:
# JS_1.json
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# ...
